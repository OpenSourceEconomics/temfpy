# %%
# TODO: This cell will be gone once you have a proper setup.
import sys 
sys.path.insert(0, "../../../")

# %% [markdown]
# # Optimization: Robustness of results

# %% [markdown]
# This notebook showcases the usefulness of `tespy` to investigate the robustness of optimization results to different starting values. We import a suitable test function from the library. For details on the `ackley` function itself, plese consult our online documentation at [tespy.readthedocs.org]()

# %%
from tespy.optimization import ackley

# %% [markdown]
# We will leave the parameterization of the function set to its default values $A = 10$ and also focus on optimization problems of dimension $n = 5$. In what follows we simply draw 15 alternative starting values and run the Powell algorithm (Powell (1964)) as implemented in `scipy`.

# %%
from scipy.optimize import minimize 
import numpy as np


rslt = list()
for iter_ in range(15):
    x0 = np.random.uniform(low=-5.12, high=5.12, size=5)
    fun = minimize(ackley, x0, method="Nelder-Mead")['fun']
    
    rslt.append(fun)

# %% [markdown]
# Now we are able to visualize the results.

# %%
import matplotlib.pyplot as plt

ax = plt.subplot()

ax.plot(rslt)

ax.set_ylabel("Function value")
ax.set_ylabel("Random point");

# %% [markdown]
# ## References

# %% [markdown]
# * Powell ...
